# %%
import numpy as np
import pandas as pd
import feather
import plotly

# %%
import plotly.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.grid_objs import Grid, Column
from plotly.graph_objs import *
from IPython.display import display, HTML

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
#x = np.random.randn(2000)
#y = np.random.randn(2000)
#iplot([Histogram2dContour(x=x, y=y, contours=Contours(coloring='heatmap')),
#       Scatter(x=x, y=y, mode='markers', marker=Marker(color='white', size=3, opacity=0.3))], show_link=False)

# %%
# from IPython.display import display, HTML

# init_notebook_mode(connected=True)

# figure = {'data': [{'x': [0, 1], 'y': [0, 1]}],
#           'layout': {'xaxis': {'range': [0, 5], 'autorange': False},
#                      'yaxis': {'range': [0, 5], 'autorange': False},
#                      'title': 'Start Title',
#                      'updatemenus': [{'type': 'buttons',
#                                       'buttons': [{'label': 'Play',
#                                                    'method': 'animate',
#                                                    'args': [None]}]}]
#                     },
#           'frames': [{'data': [{'x': [1, 2], 'y': [1, 2]}]},
#                      {'data': [{'x': [1, 4], 'y': [1, 4]}]},
#                      {'data': [{'x': [3, 4], 'y': [3, 4]}],
#                       'layout': {'title': 'End Title'}}]}

# iplot(figure)

# %% [markdown]
# # Get dataframe

# %%
antiflu = feather.read_dataframe('..\\..\\Data\\Datathon_2017\\antiflu_sample_data')

# %%
antiflu[['Patient_ID','lat','long']].head(2)
# Out:
#    Patient_ID        lat        long
# 0       295.0 -38.049427  145.119773
# 1       295.0 -38.049427  145.119773

# %%
x = np.transpose(np.array(antiflu[['long']]))[0]
y = np.transpose(np.array(antiflu[['lat']]))[0]

trace1 = Scatter(
    x=x, y=y, mode='markers', name='points',
    marker=dict(color='rgb(102,0,0)', size=2, opacity=0.4)
)

trace2 = Histogram2dcontour(
    x=x, y=y, name='density', ncontours=20,
    colorscale='Hot', reversescale=True, showscale=False
)

trace3 = Histogram(
    x=x, name='x density',
    marker=dict(color='rgb(102,0,0)'),
    yaxis='y2'
)
trace4 = Histogram(
    y=y, name='y density', marker=dict(color='rgb(102,0,0)'),
    xaxis='x2'
)
data = [trace1, trace2, trace3, trace4]

# %%
y
# Out:
# array([-38.0494265 , -38.0494265 , -38.0494265 , ..., -33.10275677,
#        -33.10275677, -33.10275677])

# %%
layout = Layout(
    showlegend=False,
    autosize=False,
    width=600,
    height=550,
    xaxis=dict(
        domain=[140, 150],
        showgrid=False,
        zeroline=False
    ),
    yaxis=dict(
        domain=[-40, -30],
        showgrid=False,
        zeroline=False
    ),
    margin=dict(
        t=50
    ),
    hovermode='closest',
    bargap=0,
    xaxis2=dict(
        domain=[140, 150],
        showgrid=False,
        zeroline=False
    ),
    yaxis2=dict(
        domain=[-40, -30],
        showgrid=False,
        zeroline=False
    )
)

# %%
# fig = Figure(data=data, layout=layout)
# iplot(Figure(data = [trace1, trace2]))

# %%
scl = [0,"rgb(150,0,90)"],[0.125,"rgb(0, 0, 200)"],[0.25,"rgb(0, 25, 255)"],
[0.375,"rgb(0, 152, 255)"],[0.5,"rgb(44, 255, 150)"],[0.625,"rgb(151, 255, 0)"],
[0.75,"rgb(255, 234, 0)"],[0.875,"rgb(255, 111, 0)"],[1,"rgb(255, 0, 0)"]

data = [ dict(
    lat = y,
    lon = x,
    marker=dict(color='rgb(102,0,0)', size=2, opacity=0.4),
    type = 'scattergeo'
), trace2 ]

#data = [ trace1, trace2 ]


layout = dict(
    geo = dict(
        scope = 'world',
        showland = True,
        landcolor = "rgb(212, 212, 212)",
        subunitcolor = "rgb(255, 255, 255)",
        countrycolor = "rgb(255, 255, 255)",
        showlakes = True,
        lakecolor = "rgb(255, 255, 255)",
        showsubunits = True,
        showcountries = True,
        resolution = 50,
        lonaxis = dict(
            showgrid = True,
            gridwidth = 0.5,
            range= [ 110, 160 ],
            dtick = 5
        ),
        lataxis = dict (
            showgrid = True,
            gridwidth = 0.5,
            range= [ -45, -15 ],
            dtick = 5
        )
    ),
    title = 'AU drugs for systemic use scatter',
)
fig = { 'data':data, 'layout':layout }
iplot(fig)
# Out:
# <div id="f7dc31c4-25cd-487f-8952-055e75e7603e" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("f7dc31c4-25cd-487f-8952-055e75e7603e", [{"marker": {"size": 2, "color": "rgb(102,0,0)", "opacity": 0.4}, "lon": [145.119773, 145.119773, 145.119773, 145.119773, 145.119773, 145.119773, 145.119773, 145.119773, 145.119773, 145.119773, 145.119773, 145.119773, 151.124235, 151.124235, 151.124235, 144.65708320000002, 144.65708320000002, 144.65708320000002, 144.65708320000002, 144.65708320000002, 144.65708320000002, 144.7322083, 144.7322083, 144.7322083, 144.7322083, 150.6418705909091, 150.6418705909091, 150.6418705909091, 150.6418705909091, 150.6418705909091, 150.6418705909091, 150.6418705909091, 150.6418705909091, 150.6418705909091, 150.6418705909091, 150.6418705909091, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 150.85899233333333, 115.78812266666667, 115.78812266666667, 115.78812266666667, 115.78812266666667, 115.78812266666667, 115.78812266666667, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.84524057142858, 150.66701083333334, 150.66701083333334, 150.66701083333334, 150.66701083333334, 150.66701083333334, 150.66701083333334, 150.66701083333334, 145.35937766666666, 145.35937766666666, 145.35937766666666, 145.35937766666666, 145.35937766666666, 145.35937766666666, 150.89780071428572, 150.89780071428572, 150.89780071428572, 150.89780071428572, 150.89780071428572, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 150.8821374285714, 147.58650835714286, 147.58650835714286, 147.58650835714286, 147.58650835714286, 147.58650835714286, 147. ...
