# %%
import numpy as np
import pandas as pd
import feather
import plotly
from tqdm import tqdm

# %%
import plotly.plotly as py
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
from plotly.grid_objs import Grid, Column
from plotly.graph_objs import *
from IPython.display import display, HTML
from datetime import datetime, timedelta

# %%
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# # Get dataframe

# %%
antiflu = feather.read_dataframe('..\\..\\Data\\Datathon_2017\\antiflu_sample_data')

# %%
antiflu[['Patient_ID','lat','long']].head(2)
# Out:
#    Patient_ID        lat        long
# 0        25.0 -36.040463  146.932638
# 1        25.0 -36.040463  146.932638

# %% [markdown]
# # init_params

# %%
grid_res = 50
lat_spacing = [ -42, -25 ]
lon_spacing = [ 135, 155 ]

# %%
lat_grid = np.linspace(lat_spacing[0],lat_spacing[1],grid_res)
lon_grid = np.linspace(lon_spacing[0],lon_spacing[1],grid_res)

# %%
def between(x,num1,num2):
    if (x < num2 and x >= num1):
        return(True)
    else:
        return(False)

# %%
def getRecordsBetweenDates(date_1,date_2):
    return antiflu[antiflu.apply( lambda x: between(x['Prescription_Week'],date_1,date_2),axis=1 ) ]

# %%
def addDaysToDate(date,days_num):
    return datetime.strftime((datetime.strptime(date,'%Y-%m-%d') + timedelta(days=days_num)),'%Y-%m-%d')

# %% [markdown]
# # 1 years worth of data here

# %%
date_list = [['2013-05-05','2013-05-19']]

for i in range(26):
    date_list.append([date_list[-1][1], addDaysToDate(date_list[-1][1],14)])

# %%
date_list
# Out:
# [['2013-05-05', '2013-05-19'],
#  ['2013-05-19', '2013-06-02'],
#  ['2013-06-02', '2013-06-16'],
#  ['2013-06-16', '2013-06-30'],
#  ['2013-06-30', '2013-07-14'],
#  ['2013-07-14', '2013-07-28'],
#  ['2013-07-28', '2013-08-11'],
#  ['2013-08-11', '2013-08-25'],
#  ['2013-08-25', '2013-09-08'],
#  ['2013-09-08', '2013-09-22'],
#  ['2013-09-22', '2013-10-06'],
#  ['2013-10-06', '2013-10-20'],
#  ['2013-10-20', '2013-11-03'],
#  ['2013-11-03', '2013-11-17'],
#  ['2013-11-17', '2013-12-01'],
#  ['2013-12-01', '2013-12-15'],
#  ['2013-12-15', '2013-12-29'],
#  ['2013-12-29', '2014-01-12'],
#  ['2014-01-12', '2014-01-26'],
#  ['2014-01-26', '2014-02-09'],
#  ['2014-02-09', '2014-02-23'],
#  ['2014-02-23', '2014-03-09'],
#  ['2014-03-09', '2014-03-23'],
#  ['2014-03-23', '2014-04-06'],
#  ['2014-04-06', '2014-04-20'],
#  ['2014-04-20', '2014-05-04'],
#  ['2014-05-04', '2014-05-18']]

# %%
getRecordsBetweenDates('2013-05-02','2013-05-10')
# Out:
#        Patient_ID  Store_ID  Prescriber_ID  Drug_ID SourceSystem_Code  \
# 699        7267.0     472.0        21473.0    504.0                 F
# 700        7267.0     472.0        21473.0    504.0                 F
# 1676     107997.0    1054.0        45562.0   2732.0                 F
# 1677     107997.0    1054.0        45562.0   2732.0                 F
# 1678     107997.0    1054.0        45562.0   2732.0                 F
# 1797     108709.0     786.0        50590.0    331.0                 F
# 2139     111563.0    2392.0        50804.0   2694.0                 F
# 2450     114203.0     586.0            0.0   1734.0                 F
THER BETA-LACTAM ANTIBACTERIALS            J01DB
# 31197      BETA-LACTAM ANTIBACTERIALS, PENICILLINS            J01CA
# 31198      BETA-LACTAM ANTIBACTERIALS, PENICILLINS            J01CA
# 31199      BETA-LACTAM ANTIBACTERIALS, PENICILLINS            J01CA
# 31665  MACROLIDES, LINCOSAMIDES AND STREPTOGRAMINS            J01FA
# 31666  MACROLIDES, LINCOSAMIDES AND STREPTOGRAMINS            J01FA
# 31667  MACROLIDES, LINCOSAMIDES AND STREPTOGRAMINS            J01FA
# 31920      BETA-LACTAM ANTIBACTERIALS, PENICILLINS            J01CA
# 31921      BETA-LACTAM ANTIBACTERIALS, PENICILLINS            J01CA
# 31922      BETA-LACTAM ANTIBACTERIALS, PENICILLINS            J01CA
# 31936      BETA-LACTAM ANTIBACTERIALS, PENICILLINS            J01CR
# 31937      BETA-LACTAM ANTIBACTERIALS, PENICILLINS            J01CR
# 31938      BETA-LACTAM ANTIBACTERIALS, PENICILLINS            J01CR
# 31939      BETA-LACTAM ANTIBACTERIALS, PENICILLINS            J01CR
# 32312                         OTHER ANTIBACTERIALS            J01XX
# 33611                                TETRACYCLINES            J01AA
# 33612                                TETRACYCLINES            J01AA
# 34131                         OTHER ANTIBACTERIALS            J01XX
# 37850                SULFONAMIDES AND TRIMETHOPRIM            J01EA
# 37851                SULFONAMIDES AND TRIMETHOPRIM            J01EA
# 37852                SULFONAMIDES AND TRIMETHOPRIM            J01EA
# 39070                     QUINOLONE ANTIBACTERIALS            J01MA
# 39071                     QUINOLONE ANTIBACTERIALS            J01MA
# 39072                     QUINOLONE ANTIBACTERIALS            J01MA
# 39339                     DIRECT ACTING ANTIVIRALS            J05AB
# 39340                     DIRECT ACTING ANTIVIRALS            J05AB
# 39341                     DIRECT ACTING ANTIVIRALS            J05AB
# 39740                                TETRACYCLINES            J01AA
# 39741                                TETRACYCLINES            J01AA
# 39742                                TETRACYCLINES            J01AA
#
#                                            ATCLevel4Name  \
# 699                   PENICILLINS WITH EXTENDED SPECTRUM
# 700                   PENICILLINS WITH EXTENDED SPECTRUM
# 1676                                       TETRACYCLINES
# 1677                                       TETRACYCLINES
# 1678                                       TETRACYCLINES
# 1797                        TRIMETHOPRIM AND DERIVATIVES
# 2139                                       TETRACYCLINES
# 2450                                    FLUOROQUINOLONES
# 2451                                    FLUOROQUINOLONES
# 2452                                    FLUOROQUINOLONES
# 3055                                       TETRACYCLINES
# 3056                                       TETRACYCLINES
# 3057                                       TETRACYCLINES
# 3945                     FIRST-GENERATION CEPHALOSPORINS
# 3946                     FIRST-GENERATION CEPHALOSPORINS
# 3947                     FIRST-GENERATION CEPHALOSPORINS
# 4346                                       TETRACYCLINES
# 4347                                       TETRACYCLINES
# 4348                                       TETRACYCLINES
# 5560                                       TETRACYCLINES
# 5561                                       TETRACYCLINES
# 5562                                       TETRACYCLINES
# 6135                                OTHER ANTIBACTERIALS
# 6136                                OTHER ANTIBACTERIALS
# 6442                                       TETRACYCLINES
# 6443                                       TETRACYCLINES
# 6875   COMBINATIONS OF SULFONAMIDES AND TRIMETHOPRIM,...
# 6876   COMBINATIONS OF SULFONAMIDES AND TRIMETHOPRIM,...
# 6877   COMBINATIONS OF SULFONAMIDES AND TRIMETHOPRIM,...
# 7143                                       TETRACYCLINES
# ...                                                  ...
# 30024                    FIRST-GENERATION CEPHALOSPORINS
# 31197                 PENICILLINS WITH EXTENDED SPECTRUM
# 31198                 PENICILLINS WITH EXTENDED SPECTRUM
# 31199                 PENICILLINS WITH EXTENDED SPECTRUM
# 31665                                         MACROLIDES
# 31666                                         MACROLIDES
# 31667                                         MACROLIDES
# 31920                 PENICILLINS WITH EXTENDED SPECTRUM
# 31921                 PENICILLINS WITH EXTENDED SPECTRUM
# 31922                 PENICILLINS WITH EXTENDED SPECTRUM
# 31936  COMBINATIONS OF PENICILLINS, INCL. BETA-LACTAM...
# 31937  COMBINATIONS OF PENICILLINS, INCL. BETA-LACTAM...
# 31938  COMBINATIONS OF PENICILLINS, INCL. BETA-LACTAM...
# 31939  COMBINATIONS OF PENICILLINS, INCL. BETA-LACTAM...
# 32312                               OTHER ANTIBACTERIALS
# 33611                                      TETRACYCLINES
# 33612                                      TETRACYCLINES
# 34131                               OTHER ANTIBACTERIALS
# 37850                       TRIMETHOPRIM AND DERIVATIVES
# 37851                       TRIMETHOPRIM AND DERIVATIVES
# 37852                       TRIMETHOPRIM AND DERIVATIVES
# 39070                                   FLUOROQUINOLONES
# 39071                                   FLUOROQUINOLONES
# 39072                                   FLUOROQUINOLONES
# 39339  NUCLEOSIDES AND NUCLEOTIDES EXCL. REVERSE TRAN...
# 39340  NUCLEOSIDES AND NUCLEOTIDES EXCL. REVERSE TRAN...
# 39341  NUCLEOSIDES AND NUCLEOTIDES EXCL. REVERSE TRAN...
# 39740                                      TETRACYCLINES
# 39741                                      TETRACYCLINES
# 39742                                      TETRACYCLINES
#
#                            ATCLevel5Name
# 699                          AMOXICILLIN
# 700                          AMOXICILLIN
# 1676                         DOXYCYCLINE
# 1677                         DOXYCYCLINE
# 1678                         DOXYCYCLINE
# 1797                        TRIMETHOPRIM
# 2139                         DOXYCYCLINE
# 2450                       CIPROFLOXACIN
# 2451                       CIPROFLOXACIN
# 2452                       CIPROFLOXACIN
# 3055                         DOXYCYCLINE
# 3056                         DOXYCYCLINE
# 3057                         DOXYCYCLINE
# 3945                           CEFALEXIN
# 3946                           CEFALEXIN
# 3947                           CEFALEXIN
# 4346                         DOXYCYCLINE
# 4347                         DOXYCYCLINE
# 4348                         DOXYCYCLINE
# 5560                         DOXYCYCLINE
# 5561                         DOXYCYCLINE
# 5562                         DOXYCYCLINE
# 6135                         METHENAMINE
# 6136                         METHENAMINE
# 6442                         MINOCYCLINE
# 6443                         MINOCYCLINE
# 6875   SULFAMETHOXAZOLE AND TRIMETHOPRIM
# 6876   SULFAMETHOXAZOLE AND TRIMETHOPRIM
# 6877   SULFAMETHOXAZOLE AND TRIMETHOPRIM
# 7143                         DOXYCYCLINE
# ...                                  ...
# 30024                          CEFALEXIN
# 31197                        AMOXICILLIN
# 31198                        AMOXICILLIN
# 31199                        AMOXICILLIN
# 31665                      ROXITHROMYCIN
# 31666                      ROXITHROMYCIN
# 31667                      ROXITHROMYCIN
# 31920                        AMOXICILLIN
# 31921                        AMOXICILLIN
# 31922                        AMOXICILLIN
# 31936   AMOXICILLIN AND ENZYME INHIBITOR
# 31937   AMOXICILLIN AND ENZYME INHIBITOR
# 31938   AMOXICILLIN AND ENZYME INHIBITOR
# 31939   AMOXICILLIN AND ENZYME INHIBITOR
# 32312                        METHENAMINE
# 33611                        MINOCYCLINE
# 33612                        MINOCYCLINE
# 34131                        METHENAMINE
# 37850                       TRIMETHOPRIM
# 37851                       TRIMETHOPRIM
# 37852                       TRIMETHOPRIM
# 39070                      CIPROFLOXACIN
# 39071                      CIPROFLOXACIN
# 39072                      CIPROFLOXACIN
# 39339                       VALACICLOVIR
# 39340                       VALACICLOVIR
# 39341                       VALACICLOVIR
# 39740                        DOXYCYCLINE
# 39741                        DOXYCYCLINE
# 39742                        DOXYCYCLINE
#
# [152 rows x 52 columns]

# %% [markdown]
# # Generate Data

# %%
colscl = [
        # Let first 10% (0.1) of the values have color rgb(0, 0, 0)
        [0, 'rgb(255, 255, 255)'],
        [0.01, 'rgb(255, 255, 255)'],

        # Let values between 10-20% of the min and max of z
        # have color rgb(20, 20, 20)
        [0.01, 'rgb(255, 255, 255)'],
        [0.04, 'rgb(255, 216, 32)'],

        # Values between 20-30% of the min and max of z
        # have color rgb(40, 40, 40)
        [0.04, 'rgb(255, 216, 32)'],
        [0.07, 'rgb(234, 35, 0)'],

        [0.07, 'rgb(234, 35, 0)'],
        [0.15, 'rgb(0, 0, 0)']
    ]

# %%
data_pts = []


for date_item in tqdm(date_list):

    tmp_df = getRecordsBetweenDates(date_item[0],date_item[1])

    x = np.transpose(np.array(tmp_df[['long']]))[0]
    y = np.transpose(np.array(tmp_df[['lat']]))[0]

    xv, yv = np.meshgrid(lat_grid[:(grid_res-1)], lon_grid[:(grid_res-1)])

    H, xedges, yedges = np.histogram2d(x,y,bins=(lon_grid,lat_grid))

    H = H / np.sum(H)

    H = H.reshape((grid_res-1)*(grid_res-1),1)
    xv = xv.reshape((grid_res-1)*(grid_res-1),1)
    yv = yv.reshape((grid_res-1)*(grid_res-1),1)

    df = pd.DataFrame(np.concatenate((H,xv,yv), axis = 1), columns=['density','lat','lon'])
    df_reduced = df[df['density'] > 0]
    #df_reduced = df

    data_pt = [ dict(
        lat = df_reduced['lat'],
        lon = df_reduced['lon'],
        text = df_reduced['density'].astype(str),
        marker = dict(
            symbol = "square-dot",
            color = df_reduced['density'],
            colorscale='Hot',
            reversescale = True,
            opacity = 0.7,
            size = 8,
            colorbar = dict(
                thickness = 10,
                titleside = "right",
                outlinecolor = "rgb(212,212,212)",
                ticks = "outside",
                ticklen = 3,
                showticksuffix = "last",
                dtick = 0.01
            ),
        ),
        type = 'scattergeo'
    ) ]
    
    if (np.sum(H) > 0):
        data_pts.append({'data' : data_pt})
# Out:
#   7%|██████▏                                                                            | 2/27 [00:01<00:15,  1.65it/s]

# %% [markdown]
# # total histogram

# %%
data = [ dict(
    lat = df_reduced['lat'],
    lon = df_reduced['lon'],
    text = df_reduced['density'].astype(str),
    marker = dict(
        color = df_reduced['density'],
        colorscale='Hot',
        reversescale = True,
        opacity = 0.7,
        size = 10,
        colorbar = dict(
            thickness = 10,
            titleside = "right",
            outlinecolor = "rgb(212,212,212)",
            ticks = "outside",
            ticklen = 3,
            showticksuffix = "last",
            dtick = 0.01
        ),
    ),
    type = 'scattergeo'
) ]

figure = {'data': data_pts[0]['data'],
         'layout': dict(
                            geo = dict(
                            scope = 'world',
                            showland = True,
                            landcolor = "rgb(212, 212, 212)",
                            subunitcolor = "rgb(255, 255, 255)",
                            countrycolor = "rgb(255, 255, 255)",
                            showlakes = True,
                            lakecolor = "rgb(255, 255, 255)",
                            showsubunits = True,
                            showcountries = True,
                            resolution = 50,
                            lonaxis = dict(
                                showgrid = True,
                                gridwidth = 0.5,
                                range= lon_spacing,
                                dtick = (lon_spacing[1]-lon_spacing[0])/grid_res*10
                            ),
                            lataxis = dict (
                                showgrid = True,
                                gridwidth = 0.5,
                                range= lat_spacing,
                                dtick = (lat_spacing[1]-lat_spacing[0])/grid_res*10
                            )
                            ),
         updatemenus = [{'type': 'buttons',
                                  'buttons': [{'label': 'Play',
                                               'method': 'animate',
                                               'args': [None]}]}],
            title = 'AU drugs for systemic use scatter'
        ),
        'frames' : data_pts
         }


iplot(figure)
