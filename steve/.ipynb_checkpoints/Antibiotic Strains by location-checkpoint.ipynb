# %%
library(tidyverse)
library(feather)
library(plotly)
library(caret)
library("ggmap")
library(maptools)
library(maps)
# Out:
# Loading tidyverse: ggplot2
# Loading tidyverse: tibble
# Loading tidyverse: tidyr
# Loading tidyverse: readr
# Loading tidyverse: purrr
# Loading tidyverse: dplyr
# Conflicts with tidy packages ---------------------------------------------------
# filter(): dplyr, stats
# lag():    dplyr, stats
#
# Attaching package: 'plotly'
#
# The following object is masked from 'package:ggplot2':
#
#     last_plot
#
# The following object is masked from 'package:stats':
#
#     filter
#
# The following object is masked from 'package:graphics':
#
#     layout
#
# Loading required package: lattice
#
# Attaching package: 'caret'
#
# The following object is masked from 'package:purrr':
#
#     lift
#
# Warning message:
# "package 'ggmap' was built under R version 3.3.3"
# Attaching package: 'ggmap'
#
# The following object is masked from 'package:plotly':
#
#     wind
#
# Warning message:
# "package 'maptools' was built under R version 3.3.3"Loading required package: sp
# Warning message:
# "package 'sp' was built under R version 3.3.3"Checking rgeos availability: FALSE
#  	Note: when rgeos is not available, polygon geometry 	computations in maptools depend on gpclib,
#  	which has a restricted licence. It is disabled by default;
#  	to enable gpclib, type gpclibPermit()
# Warning message:
# "package 'maps' was built under R version 3.3.3"
# Attaching package: 'maps'
#
# The following object is masked from 'package:purrr':
#
#     map

# %%
transactions <- feather::read_feather('..\\..\\Data\\Datathon_2017\\Transactions_Frame')
# Out:
# Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"

# %%
ATC_Lookup <- feather::read_feather('..\\..\\Data\\Datathon_2017\\ATC_Lookup')
ChronicIllness_LookUp <- feather::read_feather('..\\..\\Data\\Datathon_2017\\ChronicIllness_LookUp')
Drug_LookUp <- feather::read_feather('..\\..\\Data\\Datathon_2017\\Drug_LookUp')
patients <- feather::read_feather('..\\..\\Data\\Datathon_2017\\patients')
stores <- feather::read_feather('..\\..\\Data\\Datathon_2017\\stores')
# Out:
# Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"Warning message:
# "Coercing int64 to double"

# %%
getPostCode <- function(postcode){

    visited <- c(paste("Australia",postcode,sep = ""))
    ll.visited <- geocode(visited)
    visit.x <- ll.visited$lon
    visit.y <- ll.visited$lat
    return(c(visit.x,visit.y))
    
    }

# %%
postcodes <- read.csv('..\\..\\Data\\Datathon_2017\\Australian_Post_Codes_Lat_Lon.csv')

# %%
getPostCode("3168")[2]
# Out:
# Information from URL : http://maps.googleapis.com/maps/api/geocode/json?address=Australia3168&sensor=false
# [1] -37.9212

# %%
patient_ids <- transactions %>% select(Patient_ID) %>% unique
sample_patient_id_ix <- sample(1:nrow(patient_ids))[1:(0.10*nrow(patient_ids))]
sample_patient_ids <- patient_ids[sample_patient_id_ix,]

# %%
transactions <- transactions %>% filter(Patient_ID %in% sample_patient_ids$Patient_ID)

# %%
antibiotic_transactions <- transactions %>% 
    left_join(patients, by='Patient_ID') %>% 
    left_join(postcodes %>% group_by(postcode) %>%
                summarise(lat = mean(lat),
                  long = mean(lon))
        , by='postcode') %>% 
    left_join(., Drug_LookUp, by = c('Drug_ID'='MasterProductID')) %>%
    left_join(., ATC_Lookup, by = 'ATCLevel5Code') %>% 
    filter(stringr::str_detect(stringr::str_to_lower(ATCLevel2Name),pattern='antibacterial'))

# %%
antibiotic_transactions %>% head(3)
# Out:
#   Patient_ID Store_ID Prescriber_ID Drug_ID SourceSystem_Code Prescription_Week
# 1 309        2315     2644          223     F                 2010-11-21
# 2 309        2315     2644          223     F                 2011-03-27
# 3 309        2315     2644          223     F                 2011-03-27
#   Dispense_Week Drug_Code NHS_Code IsDeferredScript ... ATCLevel1Code.x
# 1 2011-01-16    AKAM1     1616C    0                ... J
# 2 2011-05-15    AKAM1     1616C    0                ... J
# 3 2011-06-12    AKAM1     1616C    0                ... J
#   ATCLevel1Code.y ATCLevel1Name                   ATCLevel2Code.y
# 1 J               ANTIINFECTIVES FOR SYSTEMIC USE J01
# 2 J               ANTIINFECTIVES FOR SYSTEMIC USE J01
# 3 J               ANTIINFECTIVES FOR SYSTEMIC USE J01
#   ATCLevel2Name                   ATCLevel3Code.y ATCLevel3Name ATCLevel4Code.y
# 1 ANTIBACTERIALS FOR SYSTEMIC USE J01A            TETRACYCLINES J01AA
# 2 ANTIBACTERIALS FOR SYSTEMIC USE J01A            TETRACYCLINES J01AA
# 3 ANTIBACTERIALS FOR SYSTEMIC USE J01A            TETRACYCLINES J01AA
#   ATCLevel4Name ATCLevel5Name
# 1 TETRACYCLINES MINOCYCLINE
# 2 TETRACYCLINES MINOCYCLINE
# 3 TETRACYCLINES MINOCYCLINE

# %%
antibiotic_transactions %>% names
# Out:
#  [1] "Patient_ID"               "Store_ID"
#  [3] "Prescriber_ID"            "Drug_ID"
#  [5] "SourceSystem_Code"        "Prescription_Week"
#  [7] "Dispense_Week"            "Drug_Code"
#  [9] "NHS_Code"                 "IsDeferredScript"
# [11] "Script_Qty"               "Dispensed_Qty"
# [13] "MaxDispense_Qty"          "PatientPrice_Amt"
# [15] "WholeSalePrice_Amt"       "GovernmentReclaim_Amt"
# [17] "RepeatsTotal_Qty"         "RepeatsLeft_Qty"
# [19] "StreamlinedApproval_Code" "gender"
# [21] "year_of_birth"            "postcode"
# [23] "lat"                      "long"
# [25] "MasterProductCode"        "MasterProductFullName"
# [27] "BrandName"                "FormCode"
# [29] "StrengthCode"             "PackSizeNumber"
# [31] "GenericIngredientName"    "EthicalSubCategoryName"
# [33] "EthicalCategoryName"      "ManufacturerCode"
# [35] "ManufacturerName"         "ManufacturerGroupID"
# [37] "ManufacturerGroupCode"    "ChemistListPrice"
# [39] "ATCLevel5Code"            "ATCLevel4Code.x"
# [41] "ATCLevel3Code.x"          "ATCLevel2Code.x"
# [43] "ATCLevel1Code.x"          "ATCLevel1Code.y"
# [45] "ATCLevel1Name"            "ATCLevel2Code.y"
# [47] "ATCLevel2Name"            "ATCLevel3Code.y"
# [49] "ATCLevel3Name"            "ATCLevel4Code.y"
# [51] "ATCLevel4Name"            "ATCLevel5Name"

# %%
antibiotic_transactions %>% 
mutate(Prescription_Week = as.Date(Prescription_Week)) %>%
# 19049 TETRACYCLINES                               J01AA
# 19050 TETRACYCLINES                               J01AA
# 19051 OTHER BETA-LACTAM ANTIBACTERIALS            J01DB
# 19052 QUINOLONE ANTIBACTERIALS                    J01MA
# 19053 QUINOLONE ANTIBACTERIALS                    J01MA
#       ATCLevel4Name
# 1     FIRST-GENERATION CEPHALOSPORINS
# 2     FIRST-GENERATION CEPHALOSPORINS
# 3     FIRST-GENERATION CEPHALOSPORINS
# 4     FIRST-GENERATION CEPHALOSPORINS
# 5     FIRST-GENERATION CEPHALOSPORINS
# 6     TETRACYCLINES
# 7     TETRACYCLINES
# 8     TETRACYCLINES
# 9     TETRACYCLINES
# 10    TETRACYCLINES
# 11    TETRACYCLINES
# 12    TETRACYCLINES
# 13    PENICILLINS WITH EXTENDED SPECTRUM
# 14    PENICILLINS WITH EXTENDED SPECTRUM
# 15    PENICILLINS WITH EXTENDED SPECTRUM
# 16    TETRACYCLINES
# 17    TETRACYCLINES
# 18    TETRACYCLINES
# 19    TETRACYCLINES
# 20    TETRACYCLINES
# 21    TETRACYCLINES
# 22    TETRACYCLINES
# 23    TETRACYCLINES
# 24    TETRACYCLINES
# 25    TETRACYCLINES
# 26    TETRACYCLINES
# 27    TETRACYCLINES
# 28    TETRACYCLINES
# 29    TETRACYCLINES
# 30    TETRACYCLINES
# ...   ...
# 19024 MACROLIDES
# 19025 TETRACYCLINES
# 19026 TETRACYCLINES
# 19027 BETA-LACTAMASE SENSITIVE PENICILLINS
# 19028 TETRACYCLINES
# 19029 TETRACYCLINES
# 19030 TETRACYCLINES
# 19031 MACROLIDES
# 19032 TETRACYCLINES
# 19033 TETRACYCLINES
# 19034 MACROLIDES
# 19035 MACROLIDES
# 19036 MACROLIDES
# 19037 BETA-LACTAMASE RESISTANT PENICILLINS
# 19038 BETA-LACTAMASE RESISTANT PENICILLINS
# 19039 MACROLIDES
# 19040 MACROLIDES
# 19041 TETRACYCLINES
# 19042 TETRACYCLINES
# 19043 FLUOROQUINOLONES
# 19044 FLUOROQUINOLONES
# 19045 COMBINATIONS OF SULFONAMIDES AND TRIMETHOPRIM, INCL. DERIVATIVES
# 19046 TETRACYCLINES
# 19047 OTHER ANTIBACTERIALS
# 19048 OTHER AMINOGLYCOSIDES
# 19049 TETRACYCLINES
# 19050 TETRACYCLINES
# 19051 FIRST-GENERATION CEPHALOSPORINS
# 19052 FLUOROQUINOLONES
# 19053 FLUOROQUINOLONES
#       ATCLevel5Name
# 1     CEFALEXIN
# 2     CEFALEXIN
# 3     CEFALEXIN
# 4     CEFALEXIN
# 5     CEFALEXIN
# 6     DOXYCYCLINE
# 7     DOXYCYCLINE
# 8     DOXYCYCLINE
# 9     DOXYCYCLINE
# 10    DOXYCYCLINE
# 11    DOXYCYCLINE
# 12    DOXYCYCLINE
# 13    AMOXICILLIN
# 14    AMOXICILLIN
# 15    AMOXICILLIN
# 16    MINOCYCLINE
# 17    MINOCYCLINE
# 18    MINOCYCLINE
# 19    DOXYCYCLINE
# 20    DOXYCYCLINE
# 21    DOXYCYCLINE
# 22    DOXYCYCLINE
# 23    DOXYCYCLINE
# 24    DOXYCYCLINE
# 25    DOXYCYCLINE
# 26    DOXYCYCLINE
# 27    DOXYCYCLINE
# 28    DOXYCYCLINE
# 29    DOXYCYCLINE
# 30    DOXYCYCLINE
# ...   ...
# 19024 ERYTHROMYCIN
# 19025 DOXYCYCLINE
# 19026 DOXYCYCLINE
# 19027 PHENOXYMETHYLPENICILLIN
# 19028 DOXYCYCLINE
# 19029 MINOCYCLINE
# 19030 DOXYCYCLINE
# 19031 CLARITHROMYCIN
# 19032 DOXYCYCLINE
# 19033 DOXYCYCLINE
# 19034 CLARITHROMYCIN
# 19035 CLARITHROMYCIN
# 19036 CLARITHROMYCIN
# 19037 FLUCLOXACILLIN
# 19038 FLUCLOXACILLIN
# 19039 CLARITHROMYCIN
# 19040 CLARITHROMYCIN
# 19041 DOXYCYCLINE
# 19042 DOXYCYCLINE
# 19043 CIPROFLOXACIN
# 19044 CIPROFLOXACIN
# 19045 SULFAMETHOXAZOLE AND TRIMETHOPRIM
# 19046 DOXYCYCLINE
# 19047 METHENAMINE
# 19048 GENTAMICIN
# 19049 DOXYCYCLINE
# 19050 DOXYCYCLINE
# 19051 CEFALEXIN
# 19052 CIPROFLOXACIN
# 19053 CIPROFLOXACIN

# %%
#Using GGPLOT, plot the Base World Map
mp <- NULL
mapWorld <- borders("world2", colour="gray50") # create a layer of borders
mp <- ggplot() + mapWorld + xlim(110, 157) + ylim(-44,-10)
#mp
#Now Layer the cities on top
#mp <- mp+ geom_point(aes(x=visit.x, y=visit.y) ,color="blue", size=3) 
#mp

# %%
addWeeks <- function(x){
    return(as.Date('2013-04-28') + lubridate::weeks(x))
}

# %%
lapply(X = 1:5, addWeeks)
# Out:
# [[1]]
# [1] "2013-05-05"
#
# [[2]]
# [1] "2013-05-12"
#
# [[3]]
# [1] "2013-05-19"
#
# [[4]]
# [1] "2013-05-26"
#
# [[5]]
# [1] "2013-06-02"

# %%
PlotAntibioticDensityForWeek <- function(date){
    #Sys.sleep(2)
    return(
    antibiotic_transactions %>% 
    mutate(Prescription_Week = as.Date(Prescription_Week)) %>%
    filter(Prescription_Week == as.Date(date)) %>%
    ggplot(aes(long, lat)) + mapWorld + stat_density2d(aes(alpha=..level..), geom="polygon") +
          scale_alpha_continuous(limits=c(0,0.2),breaks=seq(0,0.2,by=0.025))+
          geom_point(colour="red",alpha=0.02)+
          theme_bw() + xlim(110, 157) + ylim(-44,-10)
    )
}

# %%
PlotAntibioticDensityForWeek('2013-06-02')
# Out:
# plot without title

# %% [markdown]
# # 6 months worth of density plots...

# %%
lapply(lapply(X = 1:26, addWeeks), PlotAntibioticDensityForWeek)
